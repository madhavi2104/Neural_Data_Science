# %% [markdown]
# _Neural Data Science_
#
# Lecturer: Jan Lause, Prof. Dr. Philipp Berens
#
# Tutors: Jonas Beck, Rita González Márquez, Fabio Seel
#
# Summer term 2024
#
# Student names: <span style='background: yellow'>*Lalitha Sivakumar, Madhavi Sen, Kübra Özdemir * </span>
#
# # Coding Lab 1
#
# - __Data__: Download the data file ```nds_cl_1.csv``` from ILIAS and save it in a subfolder ```../data/```.
# - __Dependencies__: You don't have to use the exact versions of all the dependencies in this notebook, as long as they are new enough. But if you run "Run All" in Jupyter and the boilerplate code breaks, you probably need to upgrade them.
#
#
# Recommended folder structure:
#
# ```
# .
# ├── data/
# │   └── nds_cl_1.csv
# ├── notebooks
# │   └── CodingLab1.ipynb
# ├── matplotlib_style.txt
# └── requirements.txt
# ```

# %%
# !pip install jupyter_black
# !pip install watermark
# Out:
# Requirement already satisfied: jupyter_black in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (0.3.4)
# Requirement already satisfied: ipython>=7 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from jupyter_black) (8.4.0)
# Requirement already satisfied: black>=21 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from jupyter_black) (24.4.1)
# Requirement already satisfied: tokenize-rt>=4 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from jupyter_black) (5.2.0)
# Requirement already satisfied: platformdirs>=2 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from black>=21->jupyter_black) (2.6.2)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from black>=21->jupyter_black) (0.12.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from black>=21->jupyter_black) (8.1.7)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from black>=21->jupyter_black) (2.0.1)
# Requirement already satisfied: packaging>=22.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from black>=21->jupyter_black) (24.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from black>=21->jupyter_black) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from black>=21->jupyter_black) (4.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (2.12.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (63.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (3.0.30)
# Requirement already satisfied: backcall in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (5.8.1)
# Requirement already satisfied: colorama in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (0.4.5)
# Requirement already satisfied: matplotlib-inline in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (0.1.3)
# Requirement already satisfied: pickleshare in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (0.3.0)
# Requirement already satisfied: decorator in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7->jupyter_black) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=7->jupyter_black) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7->jupyter_black) (0.2.5)
# Requirement already satisfied: executing in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=7->jupyter_black) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=7->jupyter_black) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=7->jupyter_black) (0.2.2)
# Requirement already satisfied: six in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from asttokens->stack-data->ipython>=7->jupyter_black) (1.16.0)
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: watermark in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (2.4.3)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from watermark) (7.1.0)
# Requirement already satisfied: ipython>=6.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from watermark) (8.4.0)
# Requirement already satisfied: setuptools in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from watermark) (63.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=1.4->watermark) (3.18.1)
# Requirement already satisfied: decorator in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.0->watermark) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.0->watermark) (0.3.0)
# Requirement already satisfied: matplotlib-inline in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.0->watermark) (0.1.3)
# Requirement already satisfied: colorama in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.0->watermark) (0.4.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.0->watermark) (2.12.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.0->watermark) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.0->watermark) (0.7.5)
# Requirement already satisfied: traitlets>=5 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.0->watermark) (5.8.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.0->watermark) (3.0.30)
# Requirement already satisfied: backcall in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.0->watermark) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.0->watermark) (0.2.5)
# Requirement already satisfied: executing in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=6.0->watermark) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=6.0->watermark) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=6.0->watermark) (2.0.5)
# Requirement already satisfied: six in c:\users\lalitha sivakumar\appdata\local\programs\python\python310\lib\site-packages (from asttokens->stack-data->ipython>=6.0->watermark) (1.16.0)
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal  # signal processing
from sklearn.decomposition import PCA
from __future__ import annotations  # for Python 3.8 and below

# black is a code formatter (see https://github.com/psf/black).
# It will automatically format the code you write in the cells imposing consistent Python style.
# %load_ext jupyter_black

# %load_ext watermark
# %watermark --time --date --timezone --updated --python --iversions --watermark -p sklearn
# Out:
# The jupyter_black extension is already loaded. To reload it, use:
#   %reload_ext jupyter_black
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Last updated: 2024-04-25 17:00:13W. Europe Daylight Time
#
# Python implementation: CPython
# Python version       : 3.10.8
# IPython version      : 8.4.0
#
# sklearn: 1.1.1
#
# matplotlib: 3.5.2
# pandas    : 1.4.3
# scipy     : 1.8.1
# numpy     : 1.23.0
#
# Watermark: 2.4.3

# %%
# matplotlib style file
# Template for style file: https://matplotlib.org/stable/tutorials/introductory/customizing.html#customizing-with-style-sheets
plt.style.use(r"C:/Users/Lalitha Sivakumar/Downloads/CL1/matplotlib_style.txt")

# %% [markdown]
# ## Load data

# %%
fs = 30000.0  # sampling rate of the signal in Hz
dt = 1 / fs
cols = ["Ch1", "Ch2", "Ch3", "Ch4"]
x = pd.read_csv(
    r"C:/Users/Lalitha Sivakumar/Downloads/CL1/data/nds_cl_1.csv", header=0, names=cols
)

# %%
x.describe()
# Out:
#                 Ch1           Ch2           Ch3           Ch4
# count  1.920000e+07  1.920000e+07  1.920000e+07  1.920000e+07
# mean   3.600331e+00 -8.850918e-01  2.864284e-01  2.210982e+00
# std    5.824474e+02  6.014818e+02  6.464363e+02  6.126105e+02
# min   -3.607000e+03 -3.739000e+03 -3.871000e+03 -3.750000e+03
# 25%   -3.460000e+02 -3.610000e+02 -3.950000e+02 -3.640000e+02
# 50%    1.200000e+01  8.000000e+00 -1.000000e+00  1.000000e+01
# 75%    3.650000e+02  3.720000e+02  4.010000e+02  3.810000e+02
# max    2.873000e+03  3.004000e+03  3.099000e+03  3.017000e+03

# %% [markdown]
# ## Task 1: Filter Signal
#
# In order to detect action potentials, the first step is to filter out low frequency fluctuations (LFP) and high frequency noise. Determine appropriate filter settings and implement the filtering in the function ```filter_signal()```. A typical choice for this task would be a <mark>butterworth filter</mark>. Plot a segment of the raw signal and the filtered signal for all four channels with matching y-axis. The segment you choose should contain spikes. When you apply the function also test different filter settings.
#
# *Grading: 2 pts*

# %%
from scipy.signal import butter, filtfilt  # butterworth filter


def filter_signal(
    x: pd.DataFrame, fs: float, low: float, high: float, order: int = 3
) -> pd.DataFrame:
    """Filter raw signal x.

    Parameters
    ----------

    x: pd.DataFrame, (n_samples, n_channels)
        Each column in x is one recording channel.

    fs: float
        Sampling frequency.

    low, high: float, float
        Passband in Hz for the butterworth filter.

    order: int
        The order of the Butterworth filter. Default is 3, but you should try
        changing this and see how it affects the results.


    Returns
    -------

    y: pd.DataFrame, (n_samples, n_channels)
        The filtered x. The filter delay is compensated in the output y.


    Notes
    ----

    1. Try exploring different filters and filter settings. More info:
    https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.butter.html

    2. The output signal should be phase-shift compensated. More info:
    https://dsp.stackexchange.com/a/19086

    """

    # insert your code here
    y = pd.DataFrame(index=x.index, columns=x.columns)  # store filtered signals in df y
    # frequencies for the filter
    low_freq = low / fs
    high_freq = high / fs

    # --------------------------------------------------------------------
    # implement a suitable filter and apply it to the input data (1.5 pts)
    for col in x.columns:
        signal = x[col].values  # raw signal in current ch

        # butterworth filter
        b, a = butter(order, [low_freq, high_freq], btype="band")
        filtered_signal = filtfilt(
            b, a, signal
        )  # filtfilt compensates for phase shift (cancels phase delays if any)
        y[col] = filtered_signal

    return y
    # --------------------------------------------------------------------

    pass

# %%
xf = filter_signal(x, fs, 500, 4000)

# %%
mosaic = [
    ["raw: Ch1", "filtered: Ch1"],
    ["raw: Ch2", "filtered: Ch2"],
    ["raw: Ch3", "filtered: Ch3"],
    ["raw: Ch4", "filtered: Ch4"],
]
fig, ax = plt.subplot_mosaic(
    mosaic=mosaic, figsize=(8, 6), layout="constrained", dpi=100
)

# -----------------------------------------------------------------
# Plot raw and filtered signal segments for all 4 channels (0.5 pt)
for i, m in enumerate(mosaic):
    raw = m[0]
    filtered = m[1]
    ax[raw].plot(x.index / fs, x[cols[i]])
    ax[raw].set_xlim((0, 3))
    ax[raw].set_ylim((-1000, 1000))

    ax[filtered].plot(x.index / fs, xf[cols[i]])
    ax[filtered].set_xlim((0, 3))
    ax[filtered].set_ylim((-400, 250))

    ax[raw].set_ylabel("voltage")
    ax[filtered].set_title(m[1], loc="left")

    ax[raw].set_title(m[0], loc="left")

    if i != 3:
        ax[raw].set_xticklabels([])
        ax[filtered].set_xticklabels([])
    else:
        ax[raw].set_xlabel("time (s)")
        ax[filtered].set_xlabel("time (s)")

# -----------------------------------------------------------------

for i, m in enumerate(mosaic):
    raw = m[0]
    filtered = m[1]
    ax[raw].set_xlim((0, 3))
    ax[raw].set_ylim((-1000, 1000))

    ax[filtered].set_xlim((0, 3))
    ax[filtered].set_ylim((-400, 250))

    ax[raw].set_ylabel("voltage")
    ax[filtered].set_title(m[1], loc="left")

    ax[raw].set_title(m[0], loc="left")

    if i != 3:
        ax[raw].set_xticklabels([])
        ax[filtered].set_xticklabels([])
    else:
        ax[raw].set_xlabel("time (s)")
        ax[filtered].set_xlabel("time (s)")

# %% [markdown]
# ## Task 2: Detect action potentials
#
# Action potentials are usually detected by finding large-amplitude deflections in the continuous signal. A good choice of threshold for detecting spikes is important. If it is too low, you will detect too many low amplitude events (noise); if it is too high, you run the risk of missing good spikes. Implement an automatic procedure to obtain a reasonable threshold and detect the times when spikes occurred in the function ```detect_spikes()``` . Plot a segment of the filtered signal for all four channels with matching y-axis and indicate the time points where you detected spikes. **Plot the threshold**. Are the detected time points well aligned with peaks in the signal?
#
# *Grading: 3 pts*

# %%
def detect_spikes(
    x: np.ndarray, fs: float, N: int = 10, lockout: int = 12
) -> tuple[np.ndarray, np.ndarray, np.float64]:
    """Detect spikes, in this case, the relative local minima of the signal x.

    Parameters
    ----------

    x: np.array (n_samples, n_channels)
        The filtered signal from Task 1.

    fs: float
        the sampling rate (in Hz).

    N: int
        An arbitrary number with which you multiply with the standard deviation
        to set a threshold that controls your false positive rate. Default is 5
        but you should try changing it and see how it affects the results.

    lockout: int
        a window of 'refactory period', within which there's only one spike.
        Default is 10 but you should also try changing it.


    Returns
    -------

    s: np.array, (n_spikes, )
        Spike location / index in the singal x.

    t: np.array, (n_spikes, )
        Spike time in ms. By convention the time of the zeroth sample is 0 ms.

    thrd: float
        Threshold = -N * sigma.


    Tips
    ----

    Use scipy functions to detect local minima.
    Noted that there are four channels in signal x.

    """
    # insert your code here

    # -----------------------------------------------------------------------
    # compute the robust s.d. (0.5 pts) and calculate the threshold (0.5 pts)
    sigma = np.median(np.abs(x - np.median(x, axis=0)), axis=0) / 0.6745  # robust s.d
    thrd = -N * sigma
    # -----------------------------------------------------------------------
    # find all local minima (1.5 pts)
    potential_spikes = signal.argrelmin(x, axis=0, order=lockout)[0]
    spikes = potential_spikes[x[potential_spikes] < thrd]

    t = spikes / fs * 1000  # si unit ms

    return spikes, t, thrd
    # -------------------------------
    spike_indices, spike_times, threshold = detect_spikes(xf.values, fs)
    pass

# %%
mosaic = [
    ["Ch1"],
    ["Ch2"],
    ["Ch3"],
    ["Ch4"],
]
fig, ax = plt.subplot_mosaic(
    mosaic=mosaic, figsize=(8, 8), layout="constrained", dpi=100
)

# --------------------------------------------
# plot threshold and detected spikes (0.5 pts)
# Apply spike detection function to the filtered signal
spike_indices, spike_times, threshold = detect_spikes(xf.values, fs)

# Plot the threshold
for i, col in enumerate(xf.columns):
    ax[col].axhline(y=threshold[i], color="green", linestyle="--", label="Threshold")

# Plot the detected spikes
for i, (raw_col, filtered_col) in enumerate(mosaic):
    ax[filtered_col].scatter(
        spike_times,
        xf[filtered_col.split(": ")[1]][spike_indices],
        color="red",
        label="Detected Spikes",
    )

# Show the legend
for i, (raw_col, filtered_col) in enumerate(mosaic):
    ax[filtered_col].legend()

# Show plot
plt.show()


# --------------------------------------------
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [56], in <cell line: 14>()
#       7 fig, ax = plt.subplot_mosaic(
#       8     mosaic=mosaic, figsize=(8, 8), layout="constrained", dpi=100
#       9 )
#      11 # --------------------------------------------
#      12 # plot threshold and detected spikes (0.5 pts)
#      13 # Apply spike detection function to the filtered signal
# ---> 14 spike_indices, spike_times, threshold = detect_spikes(xf.values, fs)
#      16 # Plot the threshold
#      17 for i, col in enumerate(xf.columns):
#
# Input In [55], in detect_spikes(x, fs, N, lockout)
#      51 # -----------------------------------------------------------------------
#      52 # find all local minima (1.5 pts)
#      53 potential_spikes = signal.argrelmin(x, axis=0, order=lockout)[0]
# ---> 54 spikes = potential_spikes[x[potential_spikes] < thrd]
#      56 t = spikes / fs * 1000  # si unit ms
#      58 return spikes, t, thrd
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# Call detect_spikes function and assign its output to variables
spikes, spike_times, threshold = detect_spikes(xf.values, fs, N=15, lockout=12)

# Print the shape and content of spikes variable for debugging
print("Shape of spikes:", spikes.shape)
print("Spikes:", spikes)

# Plot threshold and detected spikes
for i, col in enumerate(cols):
    ax[col].plot(xf.index / fs, xf[col], label="Filtered Signal")
    ax[col].axhline(y=threshold[i], color="r", linestyle="--", label="Threshold")
    ax[col].plot(spike_times, xf[col][spikes], "rx", label="Detected Spikes")
    ax[col].legend()

    ax[col].set_ylim((-400, 400))
    ax[col].set_xlim((0.025, 0.075))
    ax[col].set_ylabel("voltage")

    ax[col].set_title(col, loc="left")

    if col != "Ch4":
        ax[col].set_xticklabels([])
    else:
        ax[col].set_xlabel("time (s)")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [44], in <cell line: 2>()
#       1 # Call detect_spikes function and assign its output to variables
# ----> 2 spikes, spike_times, threshold = detect_spikes(xf.values, fs, N=15, lockout=12)
#       4 # Print the shape and content of spikes variable for debugging
#       5 print("Shape of spikes:", spikes.shape)
#
# Input In [41], in detect_spikes(x, fs, N, lockout)
#      51 # -----------------------------------------------------------------------
#      52 # find all local minima (1.5 pts)
#      53 potential_spikes = signal.argrelmin(x, axis=0, order=lockout)[0]
# ---> 54 spikes = potential_spikes[x[potential_spikes] < thrd]
#      55 t = spikes / fs * 1000  # si unit ms
#      57 return spikes, t, thrd
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %% [markdown]
# ## Task 3: Extract waveforms
# For later spike sorting we need the waveforms of all detected spikes. Extract the waveforms segments (1 ms) on all four channels for each spike time (as a result each spike is represented by a 4x30 element matrix). Implement this procedure in the function ```extract_waveforms()```. Plot (a) the first 100 spikes you detected and (b) the 100 largest spikes you detected. Are there a lot of very small spikes (likely noise) among your detected spikes? If so your threshold may be too low. Can you see obvious artifacts, not looking like spikes at all?
#
# *Grading: 2 pts*

# %%
def extract_waveforms(x: np.ndarray, s: np.ndarray) -> np.ndarray:
    """Extract spike waveforms at times s (given in samples)
    from the filtered signal `xf` using a fixed window around the
    times othrdf the spikes.

    Parameters
    ----------

    x: np.array (n_samples, n_channels)
        The filtered signal.

    s: np.array, (n_spikes, )
        Spike time in samples.


    Return
    ------

    w: np.array, (n_spikes, length_window, n_channels)
        Waveforms. (You don't have to get the exact same
        shape as we noted here. It's just the shape of w
        that can be easily retrieved via broadcasting.)


    Notes
    -----

    More on Numpy Broadcasting
    https://jakevdp.github.io/PythonDataScienceHandbook/02.05-computation-on-arrays-broadcasting.html

    """

    # insert your code here

    # ------------------------------
    # extract spike waveforms (1 pt)
    # ------------------------------

    pass

# %% [markdown]
# Plot first 100 spike waveforms

# %%
mosaic = [
    ["Ch1", "Ch2"],
    ["Ch3", "Ch4"],
]
fig, ax = plt.subplot_mosaic(
    mosaic=mosaic, figsize=(8, 6), layout="constrained", dpi=100
)

# -------------------------------
# plot first 100 spikes (0.5 pts)
# -------------------------------

# cols = ["Ch1", "Ch2", "Ch3", "Ch4"]
for i, col in enumerate(cols):
    ax[col].set_ylim((-500, 250))
    ax[col].set_xlim((-0.33, 0.66))
    ax[col].set_title(col, loc="left")
    if col == "Ch3" or col == "Ch4":
        ax[col].set_xlabel("time (ms)")
    else:
        ax[col].set_xticklabels([])
    if col == "Ch1" or col == "Ch3":
        ax[col].set_ylabel("voltage")
    else:
        ax[col].set_yticklabels([])

# %% [markdown]
# Plot largest 100 spike waveforms

# %%
mosaic = [
    ["Ch1", "Ch2"],
    ["Ch3", "Ch4"],
]
fig, ax = plt.subplot_mosaic(
    mosaic=mosaic, figsize=(8, 6), layout="constrained", dpi=100
)

# -------------------------------------
# plot the largest 100 spikes (0.5 pts)
# -------------------------------------

# cols = ["Ch1", "Ch2", "Ch3", "Ch4"]
for i, col in enumerate(cols):
    ax[col].set_ylim((-1000, 500))
    ax[col].set_xlim((-0.33, 0.66))
    ax[col].set_title(col, loc="left")
    if col == "Ch3" or col == "Ch4":
        ax[col].set_xlabel("time (ms)")
    else:
        ax[col].set_xticklabels([])
    if col == "Ch1" or col == "Ch3":
        ax[col].set_ylabel("voltage")
    else:
        ax[col].set_yticklabels([])

# %% [markdown]
# ## Task 4: Extract features using PCA
# Compute the first three PCA features on each channel separately in ```extract_features()``` (2 pts). You can use a available PCA implementation or implement it yourself. After that, each spike is represented by a 12 element vector. Compute the fraction of variance captured by these three PCs.
# Plot scatter plots for all pairwise combinations of 1st PCs. Do you see clusters visually?
#
# *Grading: 2+1 pts*

# %% [markdown]
# ### PCA:
# - how to preprocess data?
#
#
# (https://stats.stackexchange.com/questions/385775/normalizing-vs-scaling-before-pca)

# %%
def extract_features(w: np.ndarray):
    """Extract features for spike sorting from the waveforms w.

    Do PCA on the waveforms of each channel separately,
    then concatenate the first three principal components
    of each channels into one numpy array (`b`).


    Parameter
    ---------

    w: np.ndarray, (n_spikes, length_window, n_channels)
        Waveforms from Task 3.


    Return
    ------

    b: np.ndarray, (n_spikes, n_feature)


    Notes
    -----

    You can use PCA from sklearn.

    More on PCA
    https://jakevdp.github.io/PythonDataScienceHandbook/05.09-principal-component-analysis.html

    """

    # insert your code here

    # ---------------------------------------------
    # obtain first 3 principle components (2 pts)
    # ---------------------------------------------

    # -----------------------------------------------------
    # Print the fraction of variance explained (1 pt)
    # -----------------------------------------------------

    pass

# %%
mosaic = [
    ["Ch2 vs Ch1", ".", "."],
    ["Ch3 vs Ch1", "Ch3 vs Ch2", "."],
    ["Ch4 vs Ch1", "Ch4 vs Ch2", "Ch4 vs Ch3"],
]
fig, ax = plt.subplot_mosaic(
    mosaic=mosaic, figsize=(8, 8), layout="constrained", dpi=100
)

# indices of the 1st PC in `b`
i = {"Ch1": 0, "Ch2": 3, "Ch3": 6, "Ch4": 9}

for m in np.ravel(mosaic):
    if m == ".":
        continue
    y, x = m.split(" vs ")

    ax[m].set_xlabel(x)
    ax[m].set_ylabel(y)
    ax[m].set_xlim((-1500, 1500))
    ax[m].set_ylim((-1500, 1500))
    ax[m].set_xticks([])
    ax[m].set_yticks([])

fig.suptitle("Pairwise 1st PCs", fontsize=20)
# Out:
# Text(0.5, 0.98, 'Pairwise 1st PCs')

# %%
# # save data for the next Coding Lab

# np.save("../data/nds_cl_1_features", b)
# np.save("../data/nds_cl_1_spiketimes_s", s)
# np.save("../data/nds_cl_1_spiketimes_t", t)
# np.save("../data/nds_cl_1_waveforms", w)
